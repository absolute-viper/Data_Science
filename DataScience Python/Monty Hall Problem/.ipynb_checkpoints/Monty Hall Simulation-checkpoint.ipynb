# %% [markdown]
# #################
# # Ritik Kumar Singh (AM.EN.U4CSE20061)
# # CSE A Batch 2020
# # Monty Hall Problem
# #################

# %%
import numpy as np
import pandas as pd

# %%
# defining 3 choices
option = ['Goat','Car','Goat']
nums = [0,1,2]

# %%
##### Function to randomly arrange the 3 options
import random
def initialize_doors():
    arrange = random.sample(option,3)
    return arrange

# %%
#### Function to Hide other elements and
#### Open a door with a goat behind it
def masker(j,arrangement):
    x = random.choice(arrangement)
    i = arrangement.index(x)
    while x != "Goat":
        x = random.choice(arrangement)
        i = arrangement.index(x)
    s = set([i,j])
    temp = [x for x in nums if x not in s]
    arrangement[temp[0]] = "SELECT"
    return arrangement,temp[0]


#### Function to select a Door
def select(opt,arrangement):
    hide = arrangement[:]
    for i in nums:
        if i == opt-1: hide[i] = "HOLD"
    return masker(opt-1,hide)

# %%
#### Function to Keep or Change Current Choice
def confirm(ind_1,ind_2,arrangement,conf):
    if conf == "Yes":
        if arrangement[ind_1] == "Car":
            return True
        else: return False
    elif conf == "Change":
        if arrangement[ind_2] == "Car":
            return True
        else: return False

# %%
##### Function call for single test run on Monty Hall Simulation
def initial():
    current = initialize_doors()
    print("['Option 1', 'Option 2', 'Option 3']")
    choice = int(input("Enter an option:"))
    print("Door Chosen:",choice)
    after_select,hidden = select(choice,current)
    print(after_select)
    conf = input("Type \"Yes\" to keep the current choice or \"Change\" to select the other DOOR\t")
    print("Input: ", conf)
    if confirm(choice-1,hidden,current,conf):
        print("You WON")
    else: print("You LOOSE")
    print(current)

initial()
# Out:
# ['Option 1', 'Option 2', 'Option 3']
# Enter an option:3
# Door Chosen: 3
# ['SELECT', 'Goat', 'HOLD']
# Type "Yes" to keep the current choice or "Change" to select the other DOOR	Yes
# Input:  Yes
# You LOOSE
# ['Car', 'Goat', 'Goat']

# %%
##### Function call for simulating Monty Hall Problem
def simulation(choice,conf):
    current = initialize_doors()
    after_select,hidden = select(choice,current)
    if confirm(choice-1,hidden,current,conf):
        return True
    return False

# %%
###### Simulating Monty Hall and calculating Probability
Iteration = 5000                # No. of iteration
door_change = "Yes"             # To Open selected DOOR or Open the other DOOR
def door_choice():              # Function to randomly select a door
    return random.choice([1,2,3])

def probability(win_count,loss_count):    # Function to calculate Probability
    total = win_count+loss_count
    win_percent = (win_count/total) *100
    loss_percent = (loss_count/total) * 100
    return win_percent,loss_percent

win = loss = 0
for i in range(Iteration):
    if simulation(door_choice(),door_change):
        win += 1
    else: loss += 1
    if i%50 == 0:
        x,y = probability(win,loss)
        print("Iteration:{0}\tWin Probability:{1}\tLoss Probability:{2}".format(i,x,y))
# Out:
# Iteration:0	Win Probability:100.0	Loss Probability:0.0
# Iteration:50	Win Probability:33.33333333333333	Loss Probability:66.66666666666666
# Iteration:100	Win Probability:33.663366336633665	Loss Probability:66.33663366336634
# Iteration:150	Win Probability:35.099337748344375	Loss Probability:64.90066225165563
# Iteration:200	Win Probability:35.32338308457712	Loss Probability:64.6766169154229
# Iteration:250	Win Probability:35.45816733067729	Loss Probability:64.5418326693227
# Iteration:300	Win Probability:34.883720930232556	Loss Probability:65.11627906976744
# Iteration:350	Win Probability:35.32763532763533	Loss Probability:64.67236467236467
# Iteration:400	Win Probability:36.15960099750624	Loss Probability:63.84039900249376
# Iteration:450	Win Probability:35.033259423503324	Loss Probability:64.96674057649668
# Iteration:500	Win Probability:35.528942115768466	Loss Probability:64.47105788423154
# Iteration:550	Win Probability:34.84573502722323	Loss Probability:65.15426497277676
# Iteration:600	Win Probability:34.775374376039935	Loss Probability:65.22462562396007
# Iteration:650	Win Probability:35.02304147465438	Loss Probability:64.97695852534562
# Iteration:700	Win Probability:34.8074179743224	Loss Probability:65.19258202567761
# Iteration:750	Win Probability:33.95472703062583	Loss Probability:66.04527296937417
# Iteration:800	Win Probability:33.70786516853933	Loss Probability:66.29213483146067
# Iteration:850	Win Probability:33.490011750881315	Loss Probability:66.50998824911868
# Iteration:900	Win Probability:33.074361820199776	Loss Probability:66.92563817980022
# Iteration:950	Win Probability:33.12302839116719	Loss Probability:66.8769716088328
# Iteration:1000	Win Probability:33.166833166833165	Loss Probability:66.83316683316683
# Iteration:1050	Win Probability:33.77735490009515	Loss Probability:66.22264509990485
# Iteration:1100	Win Probability:33.69663941871026	Loss Probability:66.30336058128974
# Iteration:1150	Win Probability:33.44917463075586	Loss Probability:66.55082536924414
# Iteration:1200	Win Probability:33.72189841798502	Loss Probability:66.278101582015
# Iteration:1250	Win Probability:33.65307753796962	Loss Probability:66.34692246203038
# Iteration:1300	Win Probability:33.666410453497306	Loss Probability:66.3335895465027
# Iteration:1350	Win Probability:33.67875647668394	Loss Probability:66.32124352331607
# Iteration:1400	Win Probability:33.69022127052106	Loss Probability:66.30977872947894
# Iteration:1450	Win Probability:33.70089593383873	Loss Probability:66.29910406616126
# Iteration:1500	Win Probability:34.0439706862092	Loss Probability:65.95602931379081
# Iteration:1550	Win Probability:34.107027724049	Loss Probability:65.892972275951
# Iteration:1600	Win Probability:34.29106808244847	Loss Probability:65.70893191755152
# Iteration:1650	Win Probability:34.34282253179891	Loss Probability:65.65717746820108
# Iteration:1700	Win Probability:34.33274544385655	Loss Probability:65.66725455614343
# Iteration:1750	Win Probability:34.32324386065106	Loss Probability:65.67675613934895
# Iteration:1800	Win Probability:34.258745141588	Loss Probability:65.74125485841199
# Iteration:1850	Win Probability:34.25175580767153	Loss Probability:65.74824419232847
# Iteration:1900	Win Probability:34.29773803261441	Loss Probability:65.7022619673856
# Iteration:1950	Win Probability:34.18759610456176	Loss Probability:65.81240389543824
# Iteration:2000	Win Probability:33.93303348325837	Loss Probability:66.06696651674163
# Iteration:2050	Win Probability:33.983422720624084	Loss Probability:66.01657727937591
# Iteration:2100	Win Probability:34.41218467396478	Loss Probability:65.58781532603523
# Iteration:2150	Win Probability:34.17015341701534	Loss Probability:65.82984658298466
# Iteration:2200	Win Probability:33.89368468877783	Loss Probability:66.10631531122218
# Iteration:2250	Win Probability:33.71834740115504	Loss Probability:66.28165259884496
# Iteration:2300	Win Probability:33.550630160799656	Loss Probability:66.44936983920034
# Iteration:2350	Win Probability:33.30497660569971	Loss Probability:66.6950233943003
# Iteration:2400	Win Probability:33.319450229071215	Loss Probability:66.68054977092878
# Iteration:2450	Win Probability:33.251733986128116	Loss Probability:66.7482660138719
# Iteration:2500	Win Probability:33.06677329068373	Loss Probability:66.93322670931627
# Iteration:2550	Win Probability:33.202665621324975	Loss Probability:66.79733437867503
# Iteration:2600	Win Probability:33.179546328335256	Loss Probability:66.82045367166475
# Iteration:2650	Win Probability:33.383628819313465	Loss Probability:66.61637118068653
# Iteration:2700	Win Probability:33.39503887449093	Loss Probability:66.60496112550906
# Iteration:2750	Win Probability:33.55143584151218	Loss Probability:66.44856415848783
# Iteration:2800	Win Probability:33.48803998571939	Loss Probability:66.51196001428062
# Iteration:2850	Win Probability:33.53209400210452	Loss Probability:66.46790599789547
# Iteration:2900	Win Probability:33.64357118235091	Loss Probability:66.35642881764909
# Iteration:2950	Win Probability:33.61572348356489	Loss Probability:66.38427651643511
# Iteration:3000	Win Probability:33.52215928023992	Loss Probability:66.47784071976008
# Iteration:3050	Win Probability:33.49721402818748	Loss Probability:66.50278597181251
# Iteration:3100	Win Probability:33.47307320219284	Loss Probability:66.52692679780716
# Iteration:3150	Win Probability:33.51317042208823	Loss Probability:66.48682957791178
# Iteration:3200	Win Probability:33.427054045610745	Loss Probability:66.57294595438925
# Iteration:3250	Win Probability:33.55890495232236	Loss Probability:66.44109504767763
# Iteration:3300	Win Probability:33.56558618600424	Loss Probability:66.43441381399576
# Iteration:3350	Win Probability:33.60190987764846	Loss Probability:66.39809012235153
# Iteration:3400	Win Probability:33.69597177300794	Loss Probability:66.30402822699206
# Iteration:3450	Win Probability:33.67139959432049	Loss Probability:66.32860040567951
# Iteration:3500	Win Probability:33.59040274207369	Loss Probability:66.40959725792631
# Iteration:3550	Win Probability:33.680653337088145	Loss Probability:66.31934666291185
# Iteration:3600	Win Probability:33.60177728408775	Loss Probability:66.39822271591225
# Iteration:3650	Win Probability:33.49767187072035	Loss Probability:66.50232812927965
# Iteration:3700	Win Probability:33.450418805728184	Loss Probability:66.54958119427182
# Iteration:3750	Win Probability:33.40442548653692	Loss Probability:66.59557451346308
# Iteration:3800	Win Probability:33.43856879768482	Loss Probability:66.56143120231518
# Iteration:3850	Win Probability:33.471825499870164	Loss Probability:66.52817450012984
# Iteration:3900	Win Probability:33.37605742117406	Loss Probability:66.62394257882595
# Iteration:3950	Win Probability:33.30802328524424	Loss Probability:66.69197671475577
# Iteration:4000	Win Probability:33.41664583854037	Loss Probability:66.58335416145964
# Iteration:4050	Win Probability:33.44853122685756	Loss Probability:66.55146877314243
# Iteration:4100	Win Probability:33.430870519385515	Loss Probability:66.56912948061449
# Iteration:4150	Win Probability:33.55817875210793	Loss Probability:66.44182124789208
# Iteration:4200	Win Probability:33.515829564389435	Loss Probability:66.48417043561057
# Iteration:4250	Win Probability:33.59209597741708	Loss Probability:66.40790402258293
# Iteration:4300	Win Probability:33.50383631713555	Loss Probability:66.49616368286445
# Iteration:4350	Win Probability:33.486554814985055	Loss Probability:66.51344518501494
# Iteration:4400	Win Probability:33.35605544194502	Loss Probability:66.643944558055
# Iteration:4450	Win Probability:33.340822287126485	Loss Probability:66.65917771287351
# Iteration:4500	Win Probability:33.28149300155521	Loss Probability:66.7185069984448
# Iteration:4550	Win Probability:33.28938694792353	Loss Probability:66.71061305207647
# Iteration:4600	Win Probability:33.31884372962399	Loss Probability:66.68115627037601
# Iteration:4650	Win Probability:33.304665663298216	Loss Probability:66.69533433670179
# Iteration:4700	Win Probability:33.141884705381834	Loss Probability:66.85811529461817
# Iteration:4750	Win Probability:33.108819195958745	Loss Probability:66.89118080404126
# Iteration:4800	Win Probability:33.118100395750886	Loss Probability:66.88189960424911
# Iteration:4850	Win Probability:33.18903318903319	Loss Probability:66.8109668109668
# Iteration:4900	Win Probability:33.25851866965925	Loss Probability:66.74148133034075
# Iteration:4950	Win Probability:33.34679862654009	Loss Probability:66.65320137345991

# %%
Iteration = 5000                # No. of iteration
door_change = "Change"          # To Open selected DOOR or Open the other DOOR
for i in range(Iteration):
    if simulation(door_choice(),door_change):
        win += 1
    else: loss += 1
    if i%50 == 0:
        x,y = probability(win,loss)
        print("Iteration:{0}\tWin Probability:{1}\tLoss Probability:{2}".format(i,x,y))
# Out:
# Iteration:0	Win Probability:33.33333333333333	Loss Probability:66.66666666666666
# Iteration:50	Win Probability:33.67649970302911	Loss Probability:66.32350029697089
# Iteration:100	Win Probability:33.97373064105078	Loss Probability:66.02626935894924
# Iteration:150	Win Probability:34.265191225004855	Loss Probability:65.73480877499514
# Iteration:200	Win Probability:34.58950201884253	Loss Probability:65.41049798115746
# Iteration:250	Win Probability:34.92668063226052	Loss Probability:65.07331936773949
# Iteration:300	Win Probability:35.29522731560083	Loss Probability:64.70477268439917
# Iteration:350	Win Probability:35.47000560642871	Loss Probability:64.5299943935713
# Iteration:400	Win Probability:35.734123310498056	Loss Probability:64.26587668950194
# Iteration:450	Win Probability:36.085121995964045	Loss Probability:63.914878004035955
# Iteration:500	Win Probability:36.30249045628068	Loss Probability:63.69750954371932
# Iteration:550	Win Probability:36.56998738965952	Loss Probability:63.43001261034048
# Iteration:600	Win Probability:36.814854490269596	Loss Probability:63.185145509730404
# Iteration:650	Win Probability:37.10847637586268	Loss Probability:62.89152362413732
# Iteration:700	Win Probability:37.37940712155762	Loss Probability:62.62059287844238
# Iteration:750	Win Probability:37.576073726308465	Loss Probability:62.423926273691535
# Iteration:800	Win Probability:37.872780555076716	Loss Probability:62.127219444923284
# Iteration:850	Win Probability:38.11314305246966	Loss Probability:61.88685694753033
# Iteration:900	Win Probability:38.29859345873581	Loss Probability:61.70140654126419
# Iteration:950	Win Probability:38.61535876323307	Loss Probability:61.38464123676693
# Iteration:1000	Win Probability:38.926845525745705	Loss Probability:61.07315447425429
# Iteration:1050	Win Probability:39.167079821517106	Loss Probability:60.832920178482894
# Iteration:1100	Win Probability:39.37059498442878	Loss Probability:60.629405015571216
# Iteration:1150	Win Probability:39.58705901479434	Loss Probability:60.41294098520565
# Iteration:1200	Win Probability:39.71940009675859	Loss Probability:60.280599903241416
# Iteration:1250	Win Probability:39.881618940969446	Loss Probability:60.118381059030554
# Iteration:1300	Win Probability:40.04126329154102	Loss Probability:59.95873670845897
# Iteration:1350	Win Probability:40.229885057471265	Loss Probability:59.77011494252874
# Iteration:1400	Win Probability:40.4780503046399	Loss Probability:59.5219496953601
# Iteration:1450	Win Probability:40.70686715237948	Loss Probability:59.29313284762052
# Iteration:1500	Win Probability:40.97831102907245	Loss Probability:59.021688970927556
# Iteration:1550	Win Probability:41.18455197679744	Loss Probability:58.81544802320256
# Iteration:1600	Win Probability:41.402817754885625	Loss Probability:58.597182245114375
# Iteration:1650	Win Probability:41.57269583521275	Loss Probability:58.42730416478725
# Iteration:1700	Win Probability:41.799731383375615	Loss Probability:58.200268616624385
# Iteration:1750	Win Probability:41.94934083839431	Loss Probability:58.05065916160569
# Iteration:1800	Win Probability:42.06734303778856	Loss Probability:57.93265696221144
# Iteration:1850	Win Probability:42.314990512333964	Loss Probability:57.685009487666036
# Iteration:1900	Win Probability:42.55904941312853	Loss Probability:57.440950586871466
# Iteration:1950	Win Probability:42.727665084160556	Loss Probability:57.27233491583945
# Iteration:2000	Win Probability:42.79388658763034	Loss Probability:57.20611341236966
# Iteration:2050	Win Probability:42.98681038150617	Loss Probability:57.01318961849383
# Iteration:2100	Win Probability:43.2192648922687	Loss Probability:56.7807351077313
# Iteration:2150	Win Probability:43.420500629282614	Loss Probability:56.57949937071738
# Iteration:2200	Win Probability:43.49395917233718	Loss Probability:56.50604082766283
# Iteration:2250	Win Probability:43.59398703627086	Loss Probability:56.40601296372915
# Iteration:2300	Win Probability:43.85700588960416	Loss Probability:56.14299411039584
# Iteration:2350	Win Probability:44.10284315059176	Loss Probability:55.89715684940825
# Iteration:2400	Win Probability:44.19673017159843	Loss Probability:55.80326982840157
# Iteration:2450	Win Probability:44.410146289088715	Loss Probability:55.589853710911285
# Iteration:2500	Win Probability:44.64738034928676	Loss Probability:55.352619650713244
# Iteration:2550	Win Probability:44.749039862269896	Loss Probability:55.2509601377301
# Iteration:2600	Win Probability:44.862518089725036	Loss Probability:55.137481910274964
# Iteration:2650	Win Probability:45.02679388315253	Loss Probability:54.97320611684747
# Iteration:2700	Win Probability:45.18893650175302	Loss Probability:54.81106349824698
# Iteration:2750	Win Probability:45.297380983098954	Loss Probability:54.702619016901046
# Iteration:2800	Win Probability:45.494167414434045	Loss Probability:54.50583258556595
# Iteration:2850	Win Probability:45.599286715068146	Loss Probability:54.400713284931854
# Iteration:2900	Win Probability:45.66510568282496	Loss Probability:54.33489431717504
# Iteration:2950	Win Probability:45.70494277449377	Loss Probability:54.29505722550623
# Iteration:3000	Win Probability:45.83177102862142	Loss Probability:54.168228971378575
# Iteration:3050	Win Probability:45.95702397217737	Loss Probability:54.04297602782263
# Iteration:3100	Win Probability:46.16713985927664	Loss Probability:53.83286014072337
# Iteration:3150	Win Probability:46.288798920377864	Loss Probability:53.71120107962213
# Iteration:3200	Win Probability:46.408974515303015	Loss Probability:53.591025484696985
# Iteration:3250	Win Probability:46.53981335595685	Loss Probability:53.46018664404315
# Iteration:3300	Win Probability:46.68112275629442	Loss Probability:53.31887724370558
# Iteration:3350	Win Probability:46.796790803496584	Loss Probability:53.20320919650341
# Iteration:3400	Win Probability:46.88727532436614	Loss Probability:53.11272467563385
# Iteration:3450	Win Probability:46.95302331085079	Loss Probability:53.04697668914922
# Iteration:3500	Win Probability:47.12386778026115	Loss Probability:52.87613221973886
# Iteration:3550	Win Probability:47.281019763770324	Loss Probability:52.71898023622968
# Iteration:3600	Win Probability:47.40146494593652	Loss Probability:52.598535054063476
# Iteration:3650	Win Probability:47.543636573806495	Loss Probability:52.456363426193505
# Iteration:3700	Win Probability:47.661188369152974	Loss Probability:52.338811630847026
# Iteration:3750	Win Probability:47.777396868929266	Loss Probability:52.222603131070734
# Iteration:3800	Win Probability:47.926372003181456	Loss Probability:52.07362799681854
# Iteration:3850	Win Probability:48.062365834369	Loss Probability:51.937634165630996
# Iteration:3900	Win Probability:48.151893045725195	Loss Probability:51.8481069542748
# Iteration:3950	Win Probability:48.273935873086806	Loss Probability:51.726064126913194
# Iteration:4000	Win Probability:48.3946228196867	Loss Probability:51.6053771803133
# Iteration:4050	Win Probability:48.50292785327588	Loss Probability:51.49707214672412
# Iteration:4100	Win Probability:48.6100428524338	Loss Probability:51.3899571475662
# Iteration:4150	Win Probability:48.70505955633264	Loss Probability:51.29494044366736
# Iteration:4200	Win Probability:48.799043582219326	Loss Probability:51.200956417780674
# Iteration:4250	Win Probability:48.93525024321695	Loss Probability:51.064749756783044
# Iteration:4300	Win Probability:49.02698634555424	Loss Probability:50.97301365444575
# Iteration:4350	Win Probability:49.04288311410544	Loss Probability:50.95711688589456
# Iteration:4400	Win Probability:49.207531113711305	Loss Probability:50.79246888628869
# Iteration:4450	Win Probability:49.31753253623955	Loss Probability:50.68246746376045
# Iteration:4500	Win Probability:49.384275339437956	Loss Probability:50.615724660562044
# Iteration:4550	Win Probability:49.481729661815514	Loss Probability:50.51827033818448
# Iteration:4600	Win Probability:49.671909176127485	Loss Probability:50.328090823872515
# Iteration:4650	Win Probability:49.766863537457255	Loss Probability:50.23313646254274
# Iteration:4700	Win Probability:49.87114730440161	Loss Probability:50.12885269559839
# Iteration:4750	Win Probability:50.0461491129115	Loss Probability:49.9538508870885
# Iteration:4800	Win Probability:50.18875624936231	Loss Probability:49.81124375063769
# Iteration:4850	Win Probability:50.25885696883565	Loss Probability:49.74114303116435
# Iteration:4900	Win Probability:50.33834966165034	Loss Probability:49.66165033834966
# Iteration:4950	Win Probability:50.39694503065019	Loss Probability:49.60305496934981
