# %% [markdown]
# #################
# #Ritik Kumar Singh (AM.EN.U4CSE20061)
# #CSE A Batch 2020
# #Lab Assignment 4 (Air Quality)
# #################

# %% [markdown]
# # Part 3

# %%
#1
y4and5.plot.scatter(x="T",y="RH",s=10)
plt.show()

# %%
#2
sns.regplot(x="T",y="RH",data=y4and5)
# Out:
# <AxesSubplot:xlabel='T', ylabel='RH'>

# %%
#3
from sklearn.model_selection import train_test_split
x=y4and5['T']
y=y4and5['RH']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
tarr=x.to_numpy()
rharr=y.to_numpy()
len=rh.size

# %%
#4
def errors_product():
    tmean=y4and5['T'].mean()
    rhmean=y4and5['RH'].mean()
    errprod=0
    for i in range (len):
        errprod=errprod+(abs(tarr[i]-tmean)+abs(rharr[i]-rhmean))
    return(errprod)
def squared_errors():
    tmean=y4and5['T'].mean()
    squarprod=0
    for i in range(len):
        squarprod=squarprod+((tarr[i]-tmean)**2)
    return(squarprod)

# %%
#5
m=errors_product()/squared_errors()
c=(y4and5['RH'].mean())-m*(y4and5['T'].mean())
print("slope = ",m)
print("intercept = ",c)
# Out:
# slope =  0.27850327756350785
# intercept =  44.11999591394549

# %%
#6
sns.regplot(x="T",y="RH",data=y4and5)
# Out:
# <AxesSubplot:xlabel='T', ylabel='RH'>

# %%
#8
def TtoRH(cel):
    new_output = model.predict(cel)
    return(new_output)

# %%
#12,13
import sklearn.metrics as metrics
mae = metrics.mean_absolute_error(x_train, y_train)
mse = metrics.mean_squared_error(x_train, y_train)
rmse = np.sqrt(mse) #mse**(0.5)  
r2 = metrics.r2_score(x_test, pred_y)
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# MAE: 33.37535070140281
# MSE: 1483.9943126252504
# RMSE: 38.522646749999545
# R-Squared: -1.391441396719779e+57

# %%
#14,15,16
import numpy as np
from sklearn.linear_model import LinearRegression
x_trarr=np.array(x_train)
x_tearr=np.array(x_test)
x_train= x_trarr.reshape(-1, 1)
x_test = x_tearr.reshape(-1, 1)
model=LinearRegression()
model.fit(x_train, y_train)
pred_y=np.exp(model.predict(x_test))
pred_y
# Out:
# array([5.15185931e+09, 1.78629275e+20, 3.25963059e+19, ...,
#        1.98068601e+17, 2.84021394e+23, 1.18655294e+22])

# %%
#17
import sklearn.metrics as metrics
mae = metrics.mean_absolute_error(x_train, y_train)
mse = metrics.mean_squared_error(x_train, y_train)
rmse = np.sqrt(mse) #mse**(0.5)  
r2 = metrics.r2_score(x_test, pred_y)
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# MAE: 33.37535070140281
# MSE: 1483.9943126252504
# RMSE: 38.522646749999545
# R-Squared: -1.391441396719779e+57

# %%
plt.hist(pred_y,bins=4)
# Out:
# (array([1868.,    2.,    0.,    2.]),
#  array([1.32110274e+09, 2.43719579e+30, 4.87439158e+30, 7.31158737e+30,
#         9.74878316e+30]),
#  <BarContainer object of 4 artists>)

# %%
#19
from scipy.stats import norm
plt.plot(x, norm.pdf(x, 1.075, 0.2))
