# %% [markdown]
# #################
# # Ritik Kumar Singh (AM.EN.U4CSE20061)
# # CSE A Batch 2020
# # Lab Assignment 4 (Air Quality)
# #################

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:/Users/ritik/Jupyter Notebooks/DataSets/AirQualityUCI.csv",sep=';',decimal=',')
df.drop(['Unnamed: 16','Unnamed: 15'],axis=1,inplace=True)
df.dropna(how='any',inplace=True)
for i in range(len(df)):
     df['Time'][i]=df['Time'][i].replace('.',':')
df['Date']=pd.to_datetime(df['Date'])
df
# Out:
# C:\Users\ritik\AppData\Local\Temp\ipykernel_21372\504336372.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time'][i]=df['Time'][i].replace('.',':')
# C:\Users\ritik\AppData\Local\Temp\ipykernel_21372\504336372.py:6: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0    2004-10-03  18:00:00     2.6       1360.0     150.0      11.9
# 1    2004-10-03  19:00:00     2.0       1292.0     112.0       9.4
# 2    2004-10-03  20:00:00     2.2       1402.0      88.0       9.0
# 3    2004-10-03  21:00:00     2.2       1376.0      80.0       9.2
# ...

# %%
pd_year=df['Date'].dt.year
pd_month=df['Date'].dt.month
df['Year']=pd_year
df['Month']=pd_month
group_2004 = df.groupby('Year')
df_2004 = group_2004.get_group(2004)
group_2004 = df_2004.groupby('Month',as_index=False)
median_2004 = group_2004.agg({'CO(GT)':['median']})

# %%
#### QUES 1
import matplotlib.pyplot as plt
fig,ax = plt.subplots()
ax.plot(median_2004['Month'],median_2004['CO(GT)'])

# %%
#### QUES 2
plt.style.use('ggplot')
plt.title('Monthly Median CO Concentration In 2004')
plt.grid(True)
plt.ylabel("Sensor Response")
plt.xlabel("Month")
plt.plot(median_2004['Month'],median_2004['CO(GT)'])
